# %%
import pandas as pd

# %%
data = pd.read_csv('data/hMOF_CO2_info.csv')

# %%
data
# Out:
#                  MOF                                              MOFid  \
# 0       hMOF-2000320  Oc1c(C#Cc2cc(C#Cc3ccc(c(c3)O)C(=O)[O-])cc(c2)C...
# 1         hMOF-25635  Fc1nccc(c1)c1cc(F)nc(c1F)F.[O-]C(=O)C1=C(F)[C]...
# 2       hMOF-5009809  N#Cc1cc(C(=O)[O-])c(cc1C#Cc1cc(C#N)c(c(c1)C#N)...
# 3       hMOF-5067074  CO[CH]N1CC(O[CH2])[N]C(C1OC)(O)O[CH].COc1ccc(c...
# 4       hMOF-5010907  N=NC1C(N=N)(N=N)C2(CCC1(C(=O)[O-])C(C2N=N)(N=N...
# ...              ...                                                ...
# 137647  hMOF-5033634  Brc1cnc(c(n1)Br)Br.[O-]C(=O)C#CC#CC(=O)[O-].[O...
# 137648  hMOF-5001232  CCOc1c(N=Nc2ccc(cc2)C(=O)[O-])c(OCC)c(c(c1OCC)...
# 137649    hMOF-28373  OC1=[N]=C(O)C=C([CH]1)C1=C(O)C(=[N]=C([C]1O)O)...
# 137650  hMOF-5036239                                                NaN
# 137651  hMOF-5019405  [O-]C(=O)C#CC12C3C4C2(C2C1C3(C42C#CC(=O)[O-])C...
#
#         CO2_wc_001  CO2_wc_005  CO2_wc_01  CO2_wc_05  CO2_wc_25
# ...
